# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
N = 100
gens = 10000
for i in range(10):
    fs = np.zeros(gens)
    f = 0.1
    for gen in range(gens):
        #print(f)
        f = np.random.choice([f+1/N, f-1/N, f], 1, p = [f*(1-f), f*(1-f), f**2+(1-f)**2])[0]
        f = np.min([1, f])
        f = np.max([0, f])
        fs[gen] = f
    plt.plot(fs, '-')
